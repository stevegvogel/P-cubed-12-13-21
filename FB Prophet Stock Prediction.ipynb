# %%
import streamlit as st
from path import Path
from datetime import date
import pandas as pd

# %%
import yfinance as yf
from prophet import Prophet
from fbprophet.plot import plot_plotly
from plotly import graph_objs as go
START = "2016-01-01"
TODAY = date.today().strftime("%Y-%m-%d")
st.title("Anthon Stock Predictor")
stocks = ("AAPL","AMZN","GOOG", "NVDA", "NTFX", "ORCL", "TSLA", "FB", "PFE", "BIIB")
selected_stocks = st.selectbox("Select dataset for prediction", stocks)
n_years = st.slider("Years of Prediction:", 1,4)
period = n_years * 365
#(venv) stock prediction code
#(venv) stock prediction streamlit run main.py
def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

""" NOT OPERATING
#Read the ADP.csv data files
adp_csv = Path("Resources/adp.csv")
adp =pd.read_csv(adp_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
adp = adp.rename(columns={"Close":"adp"})
adp = adp[["adp"]]
adp

#Read the AAPL.csv data files
AAPL_csv = Path("Resources/aapl.csv")
AAPL =pd.read_csv(AAPL_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
AAPL = AAPL.rename(columns={"Close":"aapl"})
AAPL = AAPL[["aapl"]]
AAPL
"""

##Set stock to analyze
selected_stock = "AMZN"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("AMAZON:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# 2021-12-13 14:10:20.651
# ...
#   command:
#
#     streamlit run C:\Users\kubip\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2021-12-13 14:10:21.067 Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2021-12-13 14:10:21.074 NumExpr defaulting to 8 threads.
# [*********************100%***********************]  1 of 1 completed
# 2021-12-13 14:10:22.034 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# AMAZON:

# %%
##Set stock to analyze
selected_stock = "GOOG"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("GOOGLE:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2021-12-13 14:10:31.430 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# GOOGLE:

# %%
##Set stock to analyze
selected_stock = "NVDA"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("NVIDIA:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2021-12-13 14:10:39.414 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# NVIDIA:

# %%
##Set stock to analyze
selected_stock = "NFLX"

data_load_state = st.text("Load data...")
data = load_data(selected_stock)
data_load_state.text("Loading data...done!")

# Forecasting
df_train = data[['Date', 'Close']]
df_train = df_train.rename(columns= {"Date":"ds","Close":"y"})

m=Prophet()
m.fit(df_train)
future = m.make_future_dataframe (periods=period)
forecast = m.predict(future)

print("NETFLIX:")

st.subheader ('Forecast data')
st.write(forecast.tail())
st.write('forecast data')
#Fig1 = plot_plotly (m.forecast)
st.write('forecast components')
Fig2 = m.plot_components(forecast)
st.write(Fig2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2021-12-13 14:10:44.794 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# NETFLIX:

# %%
""" EXTRA WORK
st.subheader('Raco data')
st.write(data.tail())

def plot_raw_data():
    fig = go.Figure()
    fig.add_trace(go.Scatter(X = data['Date'], y = data ['close'],name = data['stock_close']))
    fig.layout.ypdate(title_text = "Time Series Data", xaxis_rangeslider_visible = True)
    st.plotly_chart(fig)
plot_raw_data
"""
# Out:
# ' EXTRA WORK\nst.subheader(\'Raco data\')\nst.write(data.tail())\n\ndef plot_raw_data():\n    fig = go.Figure()\n    fig.add_trace(go.Scatter(X = data[\'Date\'], y = data [\'close\'],name = data[\'stock_close\']))\n    fig.layout.ypdate(title_text = "Time Series Data", xaxis_rangeslider_visible = True)\n    st.plotly_chart(fig)\nplot_raw_data\n'
